# %%
import numpy as np
import matplotlib.pyplot as plt
from tfrbm import BBRBM, GBRBM
from tensorflow.examples.tutorials.mnist import input_data
import pickle

# %%
rbm_feat_c_file = pickle.load(open("/home/neo/ml1/data/light/rbm_feat_c_2048.pkl","rb"))

# %%
gbrbm = GBRBM(n_visible=2048, n_hidden=1024, learning_rate=0.01, momentum=0.95, use_tqdm=True)

# %%
errs = gbrbm.fit(rbm_feat_c_file, n_epoches=30, batch_size=1000)
# Out:
# ...
# Epoch: 0: 100%|##########| 169/169 [01:14<00:00,  2.26it/s]
# Train error: 0.0392
#
# ...
# Epoch: 1: 100%|##########| 169/169 [01:16<00:00,  2.22it/s]
# Train error: 0.0301
#
# ...
# Epoch: 2: 100%|##########| 169/169 [01:20<00:00,  2.10it/s]
# Train error: 0.0303
#
# ...
# Epoch: 3: 100%|##########| 169/169 [01:15<00:00,  2.23it/s]
# Train error: 0.0304
#
# ...
# Epoch: 4:  70%|######9   | 118/169 [00:53<00:23,  2.20it/s]
# ...
# ...
# Epoch: 28: 100%|##########| 169/169 [01:18<00:00,  2.16it/s]
# Train error: 0.0306
#
# ...
# Epoch: 29: 100%|##########| 169/169 [01:18<00:00,  2.16it/s]
# Train error: 0.0306
#
# Epoch: 0:   0%|          | 0/169 [55:35<?, ?it/s]

# %%
plt.plot(errs)
plt.show()

# %%
final_features = []
for row in rbm_feat_c_file:
    final_features.append(gbrbm.transform(row)[0])
feature_file = open("/home/neo/ml1/code/ML1_project/features/features_rbm_2048.pkl", "wb")
pickle.dump(final_features, feature_file)

# %%
final_features[1]
